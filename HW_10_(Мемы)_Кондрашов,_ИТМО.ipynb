# %% [markdown]
# <a href="https://colab.research.google.com/github/fak1kondrashov24/D4140/blob/main/HW_10_(%D0%9C%D0%B5%D0%BC%D1%8B)_%D0%9A%D0%BE%D0%BD%D0%B4%D1%80%D0%B0%D1%88%D0%BE%D0%B2%2C_%D0%98%D0%A2%D0%9C%D0%9E.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install fake_useragent

# %%
from fake_useragent import UserAgent
import requests
from bs4 import BeautifulSoup

# %%
page_link_template = 'https://knowyourmeme.com/memes/all/page/'
for number in range (1, 16):
  page_link = page_link_template + str(number)
  response = requests.get(page_link, headers={'User-Agent': UserAgent().chrome})
  soup = BeautifulSoup(response.text)
  for h2 in soup.find_all('h2'):
    print(h2.text)
# Out:
#  FirstName BunchOfNumbers
#  Stop moving like that!
#  Oh Man... He's Just Like Me!
#  Web3 Is Going Great
#  I'm Glad You Came
#  Curtain Call Challenge
#  I Actually Do Cuss A Little
#  Ate That / Thought You Ate
#  First It's A Saturday Night Thing
#  Riddle Me This, Batman
#  POV Funerals
#  Lia Thomas Swimming Controversy
#  Squidward's Tiki Land
#  There Will Be Bloodshed / Samroll
#  Womblands
#  Stepan the Cat
#  Poetry By Gary
#  Too Loud Challenge
#  Mario Steals Your Liver
#  Cat Selfie Filter
#  Full of Soup Cat
#  Your Greed Is Hurting The Economy
#  Getting Mugged? Just Say No
#  Kung Fu Panda TikToks
#  Elden Ring Anime Comparisons
#  Oh No, The Bra Fell Off
#  How Long Do Emos Live
#  Ranni the Witch (Elden Ring)
#  Something in the Way
#  Mason Troy Adams
#  Noah Verrier
#  Skete
#  Titanic Flute Vine
#  Get Your Fucking Ass Up And Work
#  Redditors in Ukraine's International Legion
#  Permanent Daylight Saving Time
#  Elden Ring In Ohio
# ...
